# %%
import cv2
import numpy as np

# %%
img = cv2.imread('C:\\Users\\Marko Visnjic\\steps\\4_marko.png',0)

# %%
img = img.flatten();

# %%
p = img.shape

# %%
print(p)
# Out:
# (784,)

# %%
np.savetxt("C:\\Users\\Marko Visnjic\\steps\\4_prenormalized.csv", img, delimiter=",", fmt="%s")
